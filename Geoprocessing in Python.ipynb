# %% [markdown]
# ## Accessing Spatial Data Files

# %% [markdown]
# ### Vector Data

# %%
import geopandas as gpd
cities = gpd.read_file("ftp://ftp.gis.oregon.gov/adminbound/citylim_2017.zip")
cities.plot()
# Out:
# <AxesSubplot:>
